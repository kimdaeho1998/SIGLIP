# %% [markdown]
# # SIGLIP Consistency Check
# Use SIGLIP text embeddings to compare current and previous summaries.

# %%
import os
import sys

# Ensure the local test module is importable
sys.path.append(os.getcwd())

from SIGLIP_test import compute_similarity, build_review

# %%
current_summary = "Minimalist logo with bold wordmark and orange accent."
previous_summary = "Minimalist brand mark with strong wordmark and warm orange highlight."

similarity = compute_similarity(current_summary, previous_summary, "google/siglip-base-patch16-224")
result = build_review(similarity, 0.8)
result
